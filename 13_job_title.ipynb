# %% [markdown]
# # <span style = "color:#156a73"  > ML engineer vs Data Scientist vs Data Analyst vs Data Engineer</span>

# %% [markdown]
# ## <span style = "color:#b3b258" >1. Data Engineer:</span>
#
# Its job is to bring the data.
#
# > Scrap data
#
# > Move/store company data
#
# > Handle and Make databases and warehouses
#
# > Build pipelines/APIs for easy access to data
#
# ### <span style = "color:red" > Skills : </snap>
#
# > Backend. Algorithms.
#
# > DBMS
#
# > Big data tools
#
# > Cloud computing
#
# > Data pipeline
#
# ## <span style = "color:#b3b258" >2. Data Analyst:</span>
#
# > Analysis of data
#
# > Cleaning and organizing
#
# > Drive stories and insights
#
# > Visualization to display data
#
# > Produce and maintain the reports. Presentations to tell the storeis in data.
#
# ### <span style = "color:red" > Skills : </snap>
#
# > Statistics
#
# > Programming. Python/R/SAS
#
# > Analytical thinking
#
# > Business acumen. understanding about the certain business
#
# > Data mining, Cleaning, munging
#
# > Data Visualization
#
# > Data Story telling. **Most important**
#
# > SQL
#
# > Advanced microsoft axcel.
#
# ## <span style = "color:#b3b258" >3. Data Scientist:</span>
#
# **A person who is best at statistics than any software engineer and best at software engineering than any statician**
#
# The man who knows both uper fields. The analyst talks about past summary. The data scientist talks about future
#
# ## <span style = "color:#b3b258" >4. ML Engineer:</span>
#
# > Deploying the Machine learning models to production ready environments.
#
# > Scalling and optimizing the model
#
# > Monitoring and maintinance of deployed models.
#
# ### <span style = "color:red" > Skills : </snap>
# > Mathematics
#
# > R/Python/java/scala
#
# > Distributed Systems
